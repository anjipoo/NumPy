# %% [markdown]
# # diff between list and array

# %% [markdown]
# ### list -> python ka hai, mutable etc
# ### array -> numpy ka hai makes n dim arrays

# %%
import numpy as np

# %%
lst=range(100)
arr=np.arange(100)

# %%
import sys #to get size of list

# %%
print(sys.getsizeof(55)*len(lst))
print(arr.itemsize*arr.size)
# Out:
# 2800
# 800

# %% [markdown]
# ## implies that array needs less to store

# %%
import time #for exec time comparison

# %%
x=list(range(10000000))
y=list(range(10000000,20000000))

#adding both and checking exec time
start=time.time()
c=[x+y for x,y in zip(x,y)] 

print("time taken:",time.time()-start)
# Out:
# time taken: 1.5090479850769043

# %%
x=np.arange(10000000)
y=np.arange(10000000,20000000)

#adding both and checking exec time
start=time.time()
c=x+y

print("time taken:",time.time()-start)
# Out:
# time taken: 0.263042688369751

# %% [markdown]
# ## implies ki same range same opn ke liye array took very less time so time efficient
