# %%
import numpy as np

# %%
arr1=np.array([1,2,3,4,5,6])
arr2=np.array([4,5,6,7,8,9])

# %%
print(arr1-arr2)
# Out:
# [-3 -3 -3 -3 -3 -3]

# %%
print(arr1+arr2)
# Out:
# [ 5  7  9 11 13 15]

# %%
print(arr1*arr2)
# Out:
# [ 4 10 18 28 40 54]

# %%
print(arr1*2)
# Out:
# [ 2  4  6  8 10 12]

# %%
arr2>3 #jidhar condition true hai udhar true aayega nahi to false
# Out:
# array([ True,  True,  True,  True,  True,  True])

# %%
arr3=np.arange(6).reshape(2,3)
arr4=np.arange(6,12).reshape(3,2)

# %%
arr3.dot(arr4)
# Out:
# array([[ 28,  31],
#        [100, 112]])

# %%
arr1.dot(arr2)
# Out:
# np.int64(154)

# %%
arr1.max(), arr2.max(), arr3.max(), arr4.max()
# Out:
# (np.int64(6), np.int64(9), np.int64(5), np.int64(11))

# %%
#using axis to find miin or max of all rows/cols
arr3.min(axis=1)
#isse all columns ke min values ka array output hoga
# Out:
# array([0, 3])

# %%
#same for sum etc
arr4.sum(axis=0)
#this will sum all rows individually and return arr of the sum
# Out:
# array([24, 27])

# %%
arr4.mean(axis=0)
# Out:
# array([8., 9.])

# %%
arr3.std()
# Out:
# np.float64(1.707825127659933)

# %%
np.median(arr2)
# Out:
# np.float64(6.5)

# %%
np.sin(arr1)
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001, -0.7568025 , -0.95892427,
#        -0.2794155 ])

# %%
np.exp(arr4)
# Out:
# array([[  403.42879349,  1096.63315843],
#        [ 2980.95798704,  8103.08392758],
#        [22026.46579481, 59874.1417152 ]])

# %% [markdown]
# ### aur bhi operations hai
# ### to be explored
