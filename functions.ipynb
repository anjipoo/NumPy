# %%
import numpy as np

# %% [markdown]
# ## 1. random `np.random()`

# %%
np.random.random()
# Out:
# 0.053420183110267305

# %% [markdown]
# ## 2. seed `np.random.seed()`
# - isse same hi value return hogi at all times

# %%
np.random.seed(1)
np.random.random()
# Out:
# 0.417022004702574

# %% [markdown]
# ## 3. uniform `np.random.uniform()`
# - give start and end and usmein se it will give a number
# - can give no. of rands reqd also

# %%
np.random.uniform(2,4)
# Out:
# 2.0002287496346898

# %%
np.random.uniform(2,4,3).reshape(1,3)
# Out:
# array([[2.37252042, 2.69112145, 2.79353495]])

# %% [markdown]
# ## 4. random int `np.random.randint()`

# %%
np.random.randint(1,10,10).reshape(5,2)
# Out:
# array([[3, 5],
#        [8, 8],
#        [2, 8],
#        [1, 7],
#        [8, 7]], dtype=int32)

# %% [markdown]
# ## 5. max/min of arr `np.max()/min()`

# %%
a=np.random.randint(1,10,5)
a
# Out:
# array([4, 9, 8, 4, 7], dtype=int32)

# %%
np.max(a)
# Out:
# np.int32(9)

# %%
np.min(a)
# Out:
# np.int32(4)

# %%
#to find index
np.argmax(a)
# Out:
# np.int64(1)

# %%
np.argmin(a)
# Out:
# np.int64(0)

# %% [markdown]
# ## q. replace all odds with -1 using where `np.where(cond, action if cond true, action if cond false)`

# %%
a[a%2==1]=-1
a
# Out:
# array([ 4, -1,  8,  4, -1], dtype=int32)

# %%
np.where(a%2==1,-1,a)
#will not change the array
# Out:
# array([ 4, -1,  8,  4, -1], dtype=int32)

# %%
a=np.random.randint(1,10,5)
a
# Out:
# array([6, 2, 4, 5, 9], dtype=int32)

# %%
np.where(a%2==1,-1,a)
# Out:
# array([ 6,  2,  4, -1, -1], dtype=int32)

# %%
a
# Out:
# array([6, 2, 4, 5, 9], dtype=int32)

# %% [markdown]
# ## 6. percentile `np.percentile()`
# - % of the array is less than that

# %%
a=np.random.randint(1,40,10)
a
# Out:
# array([24, 37, 28, 38, 20, 39,  9, 33, 35, 11], dtype=int32)

# %%
a=np.sort(a)
a
# Out:
# array([ 9, 11, 20, 24, 28, 33, 35, 37, 38, 39], dtype=int32)

# %%
np.percentile(a,25)
# Out:
# np.float64(21.0)

# %%
np.percentile(a,99)
# Out:
# np.float64(38.91)
